# %%
import streamlit as st
import joblib
import pandas as pd

# Cargar modelo entrenado
modelo = joblib.load("/content/drive/MyDrive/DATASET/modelo_rf_final.pkl")

st.set_page_config(page_title="Bienestar Laboral", layout="centered")

st.title("🌱 Evaluación de Bienestar Laboral")
st.write("Esta aplicación usa Random Forest para predecir riesgos en salud mental.")

# Entradas del usuario
edad = st.number_input("Edad", 18, 100, 30)
horas_trabajo = st.slider("Horas de trabajo al día", 4, 16, 8)
estres = st.slider("Nivel de estrés (1 bajo - 10 alto)", 1, 10, 5)
satisfaccion = st.slider("Nivel de satisfacción laboral (1 bajo - 10 alto)", 1, 10, 5)

if st.button("🔍 Evaluar"):
    datos = pd.DataFrame({
        "edad": [edad],
        "horas_trabajo": [horas_trabajo],
        "estres": [estres],
        "satisfaccion": [satisfaccion]
    })

    pred = modelo.predict(datos)[0]
    probas = modelo.predict_proba(datos)[0]

    if pred == 1:
        st.error(f"⚠️ Riesgo detectado (Probabilidad: {probas[1]:.2f})")
    else:
        st.success(f"✅ Bajo riesgo (Probabilidad: {probas[0]:.2f})")
# Out:
# 2025-09-01 23:52:02.936 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:02.937 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.124
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-09-01 23:52:03.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.145 Session state does not function when running a script without `streamlit run`
# 2025-09-01 23:52:03.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 23:52:03.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
